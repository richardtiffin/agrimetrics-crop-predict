# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_pickle('dataframe.pkl')
df.T.plot.pie(subplots=True, figsize=(10, 3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002A05DE9E358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FEE15F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FEFB828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FF13C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FF30128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FF48588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FF619E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A05FF79E48>],
#       dtype=object)
