# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_pickle('dataframe.pkl')
df.T.plot.pie(subplots=True, figsize=(100, 30), layout=(2,4), fontsize=24, legend=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028848F20AC8>,
# ...
#       dtype=object)
